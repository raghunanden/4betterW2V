# %% [markdown]
# <a href="https://colab.research.google.com/github/raghunanden/4betterW2V/blob/master/NBE_Airport.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ! pip install pgmpy
! pip install networkx

# %%
from pgmpy.models import BayesianModel
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx

# %% [markdown]
# # *Create Baysian Network*

# %%
# Starting with defining the network structure

airport_passenger_model = BayesianModel([('Count Of Passenger', 'Leaving Time'), 
                              ('Time To Reach Airport', 'Leaving Time'),
                              ('Leaving Time', 'Book A Cab'),
                              ('Leaving Time', 'Reached Early'),
                              ('Reached Early', 'Security Area Congestion'),
                              ('Reached Early', 'Waiting Area Congestion'),
                              ('Security Area Congestion', 'Time To Flight'),
                              ('Waiting Area Congestion', 'Time To Flight'),
                              ('Time To Flight', 'Food'),
                              ('Time To Flight', 'Shop'),
                              ('Time To Flight', 'Security Check')])

# %%
data = pd.read_csv("")

# %%
model.fit(data, estimator=MaximumLikelihoodEstimator)

# %%
nx.draw(airport_passenger_model, with_labels=True, font_weight='bold')
